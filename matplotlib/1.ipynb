# %%
import matplotlib.pyplot as plt
product1 = [10,20,30,40,50]
product2 = [30,50,60,20,90]
month = ['Jan','Feb','May','June','July']

plt.plot(month, product1)
plt.xlabel('mount')
plt.plot(month, product2)
plt.ylabel('sell')
plt.savefig('first_graph.jpg')
plt.show()
