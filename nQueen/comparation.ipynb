# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('Book1.csv')
input_number = data.iloc[:, 0]
# print(input_number)
iterative = data.iloc[:, 1]
# print(iterative)
recursive = data.iloc[:,2]
# print(recursive)

# %%
plt.plot(input_number,iterative,color = 'red')
plt.plot(input_number,recursive,color = 'blue')
plt.ylabel('Time(second)')
plt.xlabel('Input')
plt.show()
